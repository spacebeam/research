# %%
import itertools

# %%
match = []

# %%
games = []

# %%
match.append('Locutus')

# %%
match.append('Letabot')

# %%
match.append('Microwave')

# %%
match.append('CUNYBot')

# %%
# Trying to figure it out the subscription topics

# %%
len(list(itertools.combinations(match,2)))
# Out:
# 6

# %%
list(itertools.combinations(match,2))
# Out:
# [('Locutus', 'Letabot'),
#  ('Locutus', 'Microwave'),
#  ('Locutus', 'CUNYBot'),
#  ('Letabot', 'Microwave'),
#  ('Letabot', 'CUNYBot'),
#  ('Microwave', 'CUNYBot')]

# %%
match.append('Ecgberht')

# %%
match.append('PurpleWave')

# %%
match.append('Halo')

# %%
match.append('Crona')

# %%
match.append('StyxZ')

# %%
match.append('ZZZKBot')

# %%
match.append('TCPZerg')

# %%
# Trying to figure it out the subscription topics

# %%
list(itertools.combinations(match,2))
# Out:
# [('Locutus', 'Letabot'),
#  ('Locutus', 'Microwave'),
#  ('Locutus', 'CUNYBot'),
#  ('Locutus', 'Ecgberht'),
#  ('Locutus', 'PurpleWave'),
#  ('Locutus', 'Halo'),
#  ('Locutus', 'Crona'),
#  ('Locutus', 'StyxZ'),
#  ('Locutus', 'ZZZKBot'),
#  ('Locutus', 'TCPZerg'),
#  ('Letabot', 'Microwave'),
#  ('Letabot', 'CUNYBot'),
#  ('Letabot', 'Ecgberht'),
#  ('Letabot', 'PurpleWave'),
#  ('Letabot', 'Halo'),
#  ('Letabot', 'Crona'),
#  ('Letabot', 'StyxZ'),
#  ('Letabot', 'ZZZKBot'),
#  ('Letabot', 'TCPZerg'),
#  ('Microwave', 'CUNYBot'),
#  ('Microwave', 'Ecgberht'),
#  ('Microwave', 'PurpleWave'),
#  ('Microwave', 'Halo'),
#  ('Microwave', 'Crona'),
#  ('Microwave', 'StyxZ'),
#  ('Microwave', 'ZZZKBot'),
#  ('Microwave', 'TCPZerg'),
#  ('CUNYBot', 'Ecgberht'),
#  ('CUNYBot', 'PurpleWave'),
#  ('CUNYBot', 'Halo'),
#  ('CUNYBot', 'Crona'),
#  ('CUNYBot', 'StyxZ'),
#  ('CUNYBot', 'ZZZKBot'),
#  ('CUNYBot', 'TCPZerg'),
#  ('Ecgberht', 'PurpleWave'),
#  ('Ecgberht', 'Halo'),
#  ('Ecgberht', 'Crona'),
#  ('Ecgberht', 'StyxZ'),
#  ('Ecgberht', 'ZZZKBot'),
#  ('Ecgberht', 'TCPZerg'),
#  ('PurpleWave', 'Halo'),
#  ('PurpleWave', 'Crona'),
#  ('PurpleWave', 'StyxZ'),
#  ('PurpleWave', 'ZZZKBot'),
#  ('PurpleWave', 'TCPZerg'),
#  ('Halo', 'Crona'),
#  ('Halo', 'StyxZ'),
#  ('Halo', 'ZZZKBot'),
#  ('Halo', 'TCPZerg'),
#  ('Crona', 'StyxZ'),
#  ('Crona', 'ZZZKBot'),
#  ('Crona', 'TCPZerg'),
#  ('StyxZ', 'ZZZKBot'),
#  ('StyxZ', 'TCPZerg'),
#  ('ZZZKBot', 'TCPZerg')]

# %%
match.append('\\(4\\)CircuitBreaker.scx')

# %%
match.append('\\(3\\)Aztec2.1.scx')

# %%
match.append('\\(2\\)BlueStorm1.2.scx')

# %%
match.append('\\(4\\)Gladiator1.1.scx')

# %%
match.append('\\(3\\)GoldRush.scx')

# %%
match.append('\\(2\\)HeartbreakRidge.scx')

# %%
match.append('\\(4\\)FightingSpirit.scx')

# %%
match.append('\\(3\\)PowerBond.scx')

# %%
match.append('\\(2\\)Overwatch2.2.scx')

# %%
# bonus island round
#match.append('\\(4\\)Sparkle1.1.scx')

# %%
for x in list(itertools.combinations(match,3)): 
    if '\\' in x[2] and not '\\' in x[0] and not '\\' in x[1]:
        games.append(x)
    else:
        pass

# %%
print(len(games))
# Out:
# 495

# %%
games
# Out:
# [('Locutus', 'Letabot', '\\(4\\)CircuitBreaker.scx'),
#  ('Locutus', 'Letabot', '\\(3\\)Aztec2.1.scx'),
#  ('Locutus', 'Letabot', '\\(2\\)BlueStorm1.2.scx'),
#  ('Locutus', 'Letabot', '\\(4\\)Gladiator1.1.scx'),
#  ('Locutus', 'Letabot', '\\(3\\)GoldRush.scx'),
#  ('Locutus', 'Letabot', '\\(2\\)HeartbreakRidge.scx'),
#  ('Locutus', 'Letabot', '\\(4\\)FightingSpirit.scx'),
#  ('Locutus', 'Letabot', '\\(3\\)PowerBond.scx'),
#  ('Locutus', 'Letabot', '\\(2\\)Overwatch2.2.scx'),
#  ('Locutus', 'Microwave', '\\(4\\)CircuitBreaker.scx'),
#  ('Locutus', 'Microwave', '\\(3\\)Aztec2.1.scx'),
#  ('Locutus', 'Microwave', '\\(2\\)BlueStorm1.2.scx'),
#  ('Locutus', 'Microwave', '\\(4\\)Gladiator1.1.scx'),
#  ('Locutus', 'Microwave', '\\(3\\)GoldRush.scx'),
#  ('Locutus', 'Microwave', '\\(2\\)HeartbreakRidge.scx'),
#  ('Locutus', 'Microwave', '\\(4\\)FightingSpirit.scx'),
#  ('Locutus', 'Microwave', '\\(3\\)PowerBond.scx'),
#  ('Locutus', 'Microwave', '\\(2\\)Overwatch2.2.scx'),
#  ('Locutus', 'CUNYBot', '\\(4\\)CircuitBreaker.scx'),
#  ('Locutus', 'CUNYBot', '\\(3\\)Aztec2.1.scx'),
#  ('Locutus', 'CUNYBot', '\\(2\\)BlueStorm1.2.scx'),
#  ('Locutus', 'CUNYBot', '\\(4\\)Gladiator1.1.scx'),
#  ('Locutus', 'CUNYBot', '\\(3\\)GoldRush.scx'),
#  ('Locutus', 'CUNYBot', '\\(2\\)HeartbreakRidge.scx'),
#  ('Locutus', 'CUNYBot', '\\(4\\)FightingSpirit.scx'),
#  ('Locutus', 'CUNYBot', '\\(3\\)PowerBond.scx'),
#  ('Locutus', 'CUNYBot', '\\(2\\)Overwatch2.2.scx'),
#  ('Locutus', 'Ecgberht', '\\(4\\)CircuitBreaker.scx'),
#  ('Locutus', 'Ecgberht', '\\(3\\)Aztec2.1.scx'),
#  ('Locutus', 'Ecgberht', '\\(2\\)BlueStorm1.2.scx'),
#  ('Locutus', 'Ecgberht', '\\(4\\)Gladiator1.1.scx'),
#  ('Locutus', 'Ecgberht', '\\(3\\)GoldRush.scx'),
#  ('Locutus', 'Ecgberht', '\\(2\\)HeartbreakRidge.scx'),
#  ('Locutus', 'Ecgberht', '\\(4\\)FightingSpirit.scx'),
#  ('Locutus', 'Ecgberht', '\\(3\\)PowerBond.scx'),
#  ('Locutus', 'Ecgberht', '\\(2\\)Overwatch2.2.scx'),
#  ('Locutus', 'PurpleWave', '\\(4\\)CircuitBreaker.scx'),
#  ('Locutus', 'PurpleWave', '\\(3\\)Aztec2.1.scx'),
#  ('Locutus', 'PurpleWave', '\\(2\\)BlueStorm1.2.scx'),
#  ('Locutus', 'PurpleWave', '\\(4\\)Gladiator1.1.scx'),
#  ('Locutus', 'PurpleWave', '\\(3\\)GoldRush.scx'),
#  ('Locutus', 'PurpleWave', '\\(2\\)HeartbreakRidge.scx'),
#  ('Locutus', 'PurpleWave', '\\(4\\)FightingSpirit.scx'),
#  ('Locutus', 'PurpleWave', '\\(3\\)PowerBond.scx'),
#  ('Locutus', 'PurpleWave', '\\(2\\)Overwatch2.2.scx'),
#  ('Locutus', 'Halo', '\\(4\\)CircuitBreaker.scx'),
#  ('Locutus', 'Halo', '\\(3\\)Aztec2.1.scx'),
#  ('Locutus', 'Halo', '\\(2\\)BlueStorm1.2.scx'),
#  ('Locutus', 'Halo', '\\(4\\)Gladiator1.1.scx'),
#  ('Locutus', 'Halo', '\\(3\\)GoldRush.scx'),
#  ('Locutus', 'Halo', '\\(2\\)HeartbreakRidge.scx'),
#  ('Locutus', 'Halo', '\\(4\\)FightingSpirit.scx'),
#  ('Locutus', 'Halo', '\\(3\\)PowerBond.scx'),
#  ('Locutus', 'Halo', '\\(2\\)Overwatch2.2.scx'),
#  ('Locutus', 'Crona', '\\(4\\)CircuitBreaker.scx'),
#  ('Locutus', 'Crona', '\\(3\\)Aztec2.1.scx'),
#  ('Locutus', 'Crona', '\\(2\\)BlueStorm1.2.scx'),
#  ('Locutus', 'Crona', '\\(4\\)Gladiator1.1.scx'),
#  ('Locutus', 'Crona', '\\(3\\)GoldRush.scx'),
#  ('Locutus', 'Crona', '\\(2\\)HeartbreakRidge.scx'),
#  ('Locutus', 'Crona', '\\(4\\)FightingSpirit.scx'),
#  ('Locutus', 'Crona', '\\(3\\)PowerBond.scx'),
#  ('Locutus', 'Crona', '\\(2\\)Overwatch2.2.scx'),
#  ('Locutus', 'StyxZ', '\\(4\\)CircuitBreaker.scx'),
#  ('Locutus', 'StyxZ', '\\(3\\)Aztec2.1.scx'),
#  ('Locutus', 'StyxZ', '\\(2\\)BlueStorm1.2.scx'),
#  ('Locutus', 'StyxZ', '\\(4\\)Gladiator1.1.scx'),
#  ('Locutus', 'StyxZ', '\\(3\\)GoldRush.scx'),
#  ('Locutus', 'StyxZ', '\\(2\\)HeartbreakRidge.scx'),
#  ('Locutus', 'StyxZ', '\\(4\\)FightingSpirit.scx'),
#  ('Locutus', 'StyxZ', '\\(3\\)PowerBond.scx'),
#  ('Locutus', 'StyxZ', '\\(2\\)Overwatch2.2.scx'),
#  ('Locutus', 'ZZZKBot', '\\(4\\)CircuitBreaker.scx'),
#  ('Locutus', 'ZZZKBot', '\\(3\\)Aztec2.1.scx'),
#  ('Locutus', 'ZZZKBot', '\\(2\\)BlueStorm1.2.scx'),
#  ('Locutus', 'ZZZKBot', '\\(4\\)Gladiator1.1.scx'),
#  ('Locutus', 'ZZZKBot', '\\(3\\)GoldRush.scx'),
#  ('Locutus', 'ZZZKBot', '\\(2\\)HeartbreakRidge.scx'),
#  ('Locutus', 'ZZZKBot', '\\(4\\)FightingSpirit.scx'),
#  ('Locutus', 'ZZZKBot', '\\(3\\)PowerBond.scx'),
#  ('Locutus', 'ZZZKBot', '\\(2\\)Overwatch2.2.scx'),
#  ('Locutus', 'TCPZerg', '\\(4\\)CircuitBreaker.scx'),
#  ('Locutus', 'TCPZerg', '\\(3\\)Aztec2.1.scx'),
#  ('Locutus', 'TCPZerg', '\\(2\\)BlueStorm1.2.scx'),
#  ('Locutus', 'TCPZerg', '\\(4\\)Gladiator1.1.scx'),
#  ('Locutus', 'TCPZerg', '\\(3\\)GoldRush.scx'),
#  ('Locutus', 'TCPZerg', '\\(2\\)HeartbreakRidge.scx'),
#  ('Locutus', 'TCPZerg', '\\(4\\)FightingSpirit.scx'),
#  ('Locutus', 'TCPZerg', '\\(3\\)PowerBond.scx'),
#  ('Locutus', 'TCPZerg', '\\(2\\)Overwatch2.2.scx'),
#  ('Letabot', 'Microwave', '\\(4\\)CircuitBreaker.scx'),
#  ('Letabot', 'Microwave', '\\(3\\)Aztec2.1.scx'),
#  ('Letabot', 'Microwave', '\\(2\\)BlueStorm1.2.scx'),
#  ('Letabot', 'Microwave', '\\(4\\)Gladiator1.1.scx'),
#  ('Letabot', 'Microwave', '\\(3\\)GoldRush.scx'),
#  ('Letabot', 'Microwave', '\\(2\\)HeartbreakRidge.scx'),
#  ('Letabot', 'Microwave', '\\(4\\)FightingSpirit.scx'),
#  ('Letabot', 'Microwave', '\\(3\\)PowerBond.scx'),
#  ('Letabot', 'Microwave', '\\(2\\)Overwatch2.2.scx'),
#  ('Letabot', 'CUNYBot', '\\(4\\)CircuitBreaker.scx'),
#  ('Letabot', 'CUNYBot', '\\(3\\)Aztec2.1.scx'),
#  ('Letabot', 'CUNYBot', '\\(2\\)BlueStorm1.2.scx'),
#  ('Letabot', 'CUNYBot', '\\(4\\)Gladiator1.1.scx'),
#  ('Letabot', 'CUNYBot', '\\(3\\)GoldRush.scx'),
#  ('Letabot', 'CUNYBot', '\\(2\\)HeartbreakRidge.scx'),
#  ('Letabot', 'CUNYBot', '\\(4\\)FightingSpirit.scx'),
#  ('Letabot', 'CUNYBot', '\\(3\\)PowerBond.scx'),
#  ('Letabot', 'CUNYBot', '\\(2\\)Overwatch2.2.scx'),
#  ('Letabot', 'Ecgberht', '\\(4\\)CircuitBreaker.scx'),
#  ('Letabot', 'Ecgberht', '\\(3\\)Aztec2.1.scx'),
#  ('Letabot', 'Ecgberht', '\\(2\\)BlueStorm1.2.scx'),
#  ('Letabot', 'Ecgberht', '\\(4\\)Gladiator1.1.scx'),
#  ('Letabot', 'Ecgberht', '\\(3\\)GoldRush.scx'),
#  ('Letabot', 'Ecgberht', '\\(2\\)HeartbreakRidge.scx'),
#  ('Letabot', 'Ecgberht', '\\(4\\)FightingSpirit.scx'),
#  ('Letabot', 'Ecgberht', '\\(3\\)PowerBond.scx'),
#  ('Letabot', 'Ecgberht', '\\(2\\)Overwatch2.2.scx'),
#  ('Letabot', 'PurpleWave', '\\(4\\)CircuitBreaker.scx'),
#  ('Letabot', 'PurpleWave', '\\(3\\)Aztec2.1.scx'),
#  ('Letabot', 'PurpleWave', '\\(2\\)BlueStorm1.2.scx'),
#  ('Letabot', 'PurpleWave', '\\(4\\)Gladiator1.1.scx'),
#  ('Letabot', 'PurpleWave', '\\(3\\)GoldRush.scx'),
#  ('Letabot', 'PurpleWave', '\\(2\\)HeartbreakRidge.scx'),
#  ('Letabot', 'PurpleWave', '\\(4\\)FightingSpirit.scx'),
#  ('Letabot', 'PurpleWave', '\\(3\\)PowerBond.scx'),
#  ('Letabot', 'PurpleWave', '\\(2\\)Overwatch2.2.scx'),
#  ('Letabot', 'Halo', '\\(4\\)CircuitBreaker.scx'),
#  ('Letabot', 'Halo', '\\(3\\)Aztec2.1.scx'),
#  ('Letabot', 'Halo', '\\(2\\)BlueStorm1.2.scx'),
#  ('Letabot', 'Halo', '\\(4\\)Gladiator1.1.scx'),
#  ('Letabot', 'Halo', '\\(3\\)GoldRush.scx'),
#  ('Letabot', 'Halo', '\\(2\\)HeartbreakRidge.scx'),
#  ('Letabot', 'Halo', '\\(4\\)FightingSpirit.scx'),
#  ('Letabot', 'Halo', '\\(3\\)PowerBond.scx'),
#  ('Letabot', 'Halo', '\\(2\\)Overwatch2.2.scx'),
#  ('Letabot', 'Crona', '\\(4\\)CircuitBreaker.scx'),
#  ('Letabot', 'Crona', '\\(3\\)Aztec2.1.scx'),
#  ('Letabot', 'Crona', '\\(2\\)BlueStorm1.2.scx'),
#  ('Letabot', 'Crona', '\\(4\\)Gladiator1.1.scx'),
#  ('Letabot', 'Crona', '\\(3\\)GoldRush.scx'),
#  ('Letabot', 'Crona', '\\(2\\)HeartbreakRidge.scx'),
#  ('Letabot', 'Crona', '\\(4\\)FightingSpirit.scx'),
#  ('Letabot', 'Crona', '\\(3\\)PowerBond.scx'),
#  ('Letabot', 'Crona', '\\(2\\)Overwatch2.2.scx'),
#  ('Letabot', 'StyxZ', '\\(4\\)CircuitBreaker.scx'),
#  ('Letabot', 'StyxZ', '\\(3\\)Aztec2.1.scx'),
#  ('Letabot', 'StyxZ', '\\(2\\)BlueStorm1.2.scx'),
#  ('Letabot', 'StyxZ', '\\(4\\)Gladiator1.1.scx'),
#  ('Letabot', 'StyxZ', '\\(3\\)GoldRush.scx'),
#  ('Letabot', 'StyxZ', '\\(2\\)HeartbreakRidge.scx'),
#  ('Letabot', 'StyxZ', '\\(4\\)FightingSpirit.scx'),
#  ('Letabot', 'StyxZ', '\\(3\\)PowerBond.scx'),
#  ('Letabot', 'StyxZ', '\\(2\\)Overwatch2.2.scx'),
#  ('Letabot', 'ZZZKBot', '\\(4\\)CircuitBreaker.scx'),
#  ('Letabot', 'ZZZKBot', '\\(3\\)Aztec2.1.scx'),
#  ('Letabot', 'ZZZKBot', '\\(2\\)BlueStorm1.2.scx'),
#  ('Letabot', 'ZZZKBot', '\\(4\\)Gladiator1.1.scx'),
#  ('Letabot', 'ZZZKBot', '\\(3\\)GoldRush.scx'),
#  ('Letabot', 'ZZZKBot', '\\(2\\)HeartbreakRidge.scx'),
#  ('Letabot', 'ZZZKBot', '\\(4\\)FightingSpirit.scx'),
#  ('Letabot', 'ZZZKBot', '\\(3\\)PowerBond.scx'),
#  ('Letabot', 'ZZZKBot', '\\(2\\)Overwatch2.2.scx'),
#  ('Letabot', 'TCPZerg', '\\(4\\)CircuitBreaker.scx'),
#  ('Letabot', 'TCPZerg', '\\(3\\)Aztec2.1.scx'),
#  ('Letabot', 'TCPZerg', '\\(2\\)BlueStorm1.2.scx'),
#  ('Letabot', 'TCPZerg', '\\(4\\)Gladiator1.1.scx'),
#  ('Letabot', 'TCPZerg', '\\(3\\)GoldRush.scx'),
#  ('Letabot', 'TCPZerg', '\\(2\\)HeartbreakRidge.scx'),
#  ('Letabot', 'TCPZerg', '\\(4\\)FightingSpirit.scx'),
#  ('Letabot', 'TCPZerg', '\\(3\\)PowerBond.scx'),
#  ('Letabot', 'TCPZerg', '\\(2\\)Overwatch2.2.scx'),
#  ('Microwave', 'CUNYBot', '\\(4\\)CircuitBreaker.scx'),
#  ('Microwave', 'CUNYBot', '\\(3\\)Aztec2.1.scx'),
#  ('Microwave', 'CUNYBot', '\\(2\\)BlueStorm1.2.scx'),
#  ('Microwave', 'CUNYBot', '\\(4\\)Gladiator1.1.scx'),
#  ('Microwave', 'CUNYBot', '\\(3\\)GoldRush.scx'),
#  ('Microwave', 'CUNYBot', '\\(2\\)HeartbreakRidge.scx'),
#  ('Microwave', 'CUNYBot', '\\(4\\)FightingSpirit.scx'),
#  ('Microwave', 'CUNYBot', '\\(3\\)PowerBond.scx'),
#  ('Microwave', 'CUNYBot', '\\(2\\)Overwatch2.2.scx'),
#  ('Microwave', 'Ecgberht', '\\(4\\)CircuitBreaker.scx'),
#  ('Microwave', 'Ecgberht', '\\(3\\)Aztec2.1.scx'),
#  ('Microwave', 'Ecgberht', '\\(2\\)BlueStorm1.2.scx'),
#  ('Microwave', 'Ecgberht', '\\(4\\)Gladiator1.1.scx'),
#  ('Microwave', 'Ecgberht', '\\(3\\)GoldRush.scx'),
#  ('Microwave', 'Ecgberht', '\\(2\\)HeartbreakRidge.scx'),
#  ('Microwave', 'Ecgberht', '\\(4\\)FightingSpirit.scx'),
#  ('Microwave', 'Ecgberht', '\\(3\\)PowerBond.scx'),
#  ('Microwave', 'Ecgberht', '\\(2\\)Overwatch2.2.scx'),
#  ('Microwave', 'PurpleWave', '\\(4\\)CircuitBreaker.scx'),
#  ('Microwave', 'PurpleWave', '\\(3\\)Aztec2.1.scx'),
#  ('Microwave', 'PurpleWave', '\\(2\\)BlueStorm1.2.scx'),
#  ('Microwave', 'PurpleWave', '\\(4\\)Gladiator1.1.scx'),
#  ('Microwave', 'PurpleWave', '\\(3\\)GoldRush.scx'),
#  ('Microwave', 'PurpleWave', '\\(2\\)HeartbreakRidge.scx'),
#  ('Microwave', 'PurpleWave', '\\(4\\)FightingSpirit.scx'),
#  ('Microwave', 'PurpleWave', '\\(3\\)PowerBond.scx'),
#  ('Microwave', 'PurpleWave', '\\(2\\)Overwatch2.2.scx'),
#  ('Microwave', 'Halo', '\\(4\\)CircuitBreaker.scx'),
#  ('Microwave', 'Halo', '\\(3\\)Aztec2.1.scx'),
#  ('Microwave', 'Halo', '\\(2\\)BlueStorm1.2.scx'),
#  ('Microwave', 'Halo', '\\(4\\)Gladiator1.1.scx'),
#  ('Microwave', 'Halo', '\\(3\\)GoldRush.scx'),
#  ('Microwave', 'Halo', '\\(2\\)HeartbreakRidge.scx'),
#  ('Microwave', 'Halo', '\\(4\\)FightingSpirit.scx'),
#  ('Microwave', 'Halo', '\\(3\\)PowerBond.scx'),
#  ('Microwave', 'Halo', '\\(2\\)Overwatch2.2.scx'),
#  ('Microwave', 'Crona', '\\(4\\)CircuitBreaker.scx'),
#  ('Microwave', 'Crona', '\\(3\\)Aztec2.1.scx'),
#  ('Microwave', 'Crona', '\\(2\\)BlueStorm1.2.scx'),
#  ('Microwave', 'Crona', '\\(4\\)Gladiator1.1.scx'),
#  ('Microwave', 'Crona', '\\(3\\)GoldRush.scx'),
#  ('Microwave', 'Crona', '\\(2\\)HeartbreakRidge.scx'),
#  ('Microwave', 'Crona', '\\(4\\)FightingSpirit.scx'),
#  ('Microwave', 'Crona', '\\(3\\)PowerBond.scx'),
#  ('Microwave', 'Crona', '\\(2\\)Overwatch2.2.scx'),
#  ('Microwave', 'StyxZ', '\\(4\\)CircuitBreaker.scx'),
#  ('Microwave', 'StyxZ', '\\(3\\)Aztec2.1.scx'),
#  ('Microwave', 'StyxZ', '\\(2\\)BlueStorm1.2.scx'),
#  ('Microwave', 'StyxZ', '\\(4\\)Gladiator1.1.scx'),
#  ('Microwave', 'StyxZ', '\\(3\\)GoldRush.scx'),
#  ('Microwave', 'StyxZ', '\\(2\\)HeartbreakRidge.scx'),
#  ('Microwave', 'StyxZ', '\\(4\\)FightingSpirit.scx'),
#  ('Microwave', 'StyxZ', '\\(3\\)PowerBond.scx'),
#  ('Microwave', 'StyxZ', '\\(2\\)Overwatch2.2.scx'),
#  ('Microwave', 'ZZZKBot', '\\(4\\)CircuitBreaker.scx'),
#  ('Microwave', 'ZZZKBot', '\\(3\\)Aztec2.1.scx'),
#  ('Microwave', 'ZZZKBot', '\\(2\\)BlueStorm1.2.scx'),
#  ('Microwave', 'ZZZKBot', '\\(4\\)Gladiator1.1.scx'),
#  ('Microwave', 'ZZZKBot', '\\(3\\)GoldRush.scx'),
#  ('Microwave', 'ZZZKBot', '\\(2\\)HeartbreakRidge.scx'),
#  ('Microwave', 'ZZZKBot', '\\(4\\)FightingSpirit.scx'),
#  ('Microwave', 'ZZZKBot', '\\(3\\)PowerBond.scx'),
#  ('Microwave', 'ZZZKBot', '\\(2\\)Overwatch2.2.scx'),
#  ('Microwave', 'TCPZerg', '\\(4\\)CircuitBreaker.scx'),
#  ('Microwave', 'TCPZerg', '\\(3\\)Aztec2.1.scx'),
#  ('Microwave', 'TCPZerg', '\\(2\\)BlueStorm1.2.scx'),
#  ('Microwave', 'TCPZerg', '\\(4\\)Gladiator1.1.scx'),
#  ('Microwave', 'TCPZerg', '\\(3\\)GoldRush.scx'),
#  ('Microwave', 'TCPZerg', '\\(2\\)HeartbreakRidge.scx'),
#  ('Microwave', 'TCPZerg', '\\(4\\)FightingSpirit.scx'),
#  ('Microwave', 'TCPZerg', '\\(3\\)PowerBond.scx'),
#  ('Microwave', 'TCPZerg', '\\(2\\)Overwatch2.2.scx'),
#  ('CUNYBot', 'Ecgberht', '\\(4\\)CircuitBreaker.scx'),
#  ('CUNYBot', 'Ecgberht', '\\(3\\)Aztec2.1.scx'),
#  ('CUNYBot', 'Ecgberht', '\\(2\\)BlueStorm1.2.scx'),
#  ('CUNYBot', 'Ecgberht', '\\(4\\)Gladiator1.1.scx'),
#  ('CUNYBot', 'Ecgberht', '\\(3\\)GoldRush.scx'),
#  ('CUNYBot', 'Ecgberht', '\\(2\\)HeartbreakRidge.scx'),
#  ('CUNYBot', 'Ecgberht', '\\(4\\)FightingSpirit.scx'),
#  ('CUNYBot', 'Ecgberht', '\\(3\\)PowerBond.scx'),
#  ('CUNYBot', 'Ecgberht', '\\(2\\)Overwatch2.2.scx'),
#  ('CUNYBot', 'PurpleWave', '\\(4\\)CircuitBreaker.scx'),
#  ('CUNYBot', 'PurpleWave', '\\(3\\)Aztec2.1.scx'),
#  ('CUNYBot', 'PurpleWave', '\\(2\\)BlueStorm1.2.scx'),
#  ('CUNYBot', 'PurpleWave', '\\(4\\)Gladiator1.1.scx'),
#  ('CUNYBot', 'PurpleWave', '\\(3\\)GoldRush.scx'),
#  ('CUNYBot', 'PurpleWave', '\\(2\\)HeartbreakRidge.scx'),
#  ('CUNYBot', 'PurpleWave', '\\(4\\)FightingSpirit.scx'),
#  ('CUNYBot', 'PurpleWave', '\\(3\\)PowerBond.scx'),
#  ('CUNYBot', 'PurpleWave', '\\(2\\)Overwatch2.2.scx'),
#  ('CUNYBot', 'Halo', '\\(4\\)CircuitBreaker.scx'),
#  ('CUNYBot', 'Halo', '\\(3\\)Aztec2.1.scx'),
#  ('CUNYBot', 'Halo', '\\(2\\)BlueStorm1.2.scx'),
#  ('CUNYBot', 'Halo', '\\(4\\)Gladiator1.1.scx'),
#  ('CUNYBot', 'Halo', '\\(3\\)GoldRush.scx'),
#  ('CUNYBot', 'Halo', '\\(2\\)HeartbreakRidge.scx'),
#  ('CUNYBot', 'Halo', '\\(4\\)FightingSpirit.scx'),
#  ('CUNYBot', 'Halo', '\\(3\\)PowerBond.scx'),
#  ('CUNYBot', 'Halo', '\\(2\\)Overwatch2.2.scx'),
#  ('CUNYBot', 'Crona', '\\(4\\)CircuitBreaker.scx'),
#  ('CUNYBot', 'Crona', '\\(3\\)Aztec2.1.scx'),
#  ('CUNYBot', 'Crona', '\\(2\\)BlueStorm1.2.scx'),
#  ('CUNYBot', 'Crona', '\\(4\\)Gladiator1.1.scx'),
#  ('CUNYBot', 'Crona', '\\(3\\)GoldRush.scx'),
#  ('CUNYBot', 'Crona', '\\(2\\)HeartbreakRidge.scx'),
#  ('CUNYBot', 'Crona', '\\(4\\)FightingSpirit.scx'),
#  ('CUNYBot', 'Crona', '\\(3\\)PowerBond.scx'),
#  ('CUNYBot', 'Crona', '\\(2\\)Overwatch2.2.scx'),
#  ('CUNYBot', 'StyxZ', '\\(4\\)CircuitBreaker.scx'),
#  ('CUNYBot', 'StyxZ', '\\(3\\)Aztec2.1.scx'),
#  ('CUNYBot', 'StyxZ', '\\(2\\)BlueStorm1.2.scx'),
#  ('CUNYBot', 'StyxZ', '\\(4\\)Gladiator1.1.scx'),
#  ('CUNYBot', 'StyxZ', '\\(3\\)GoldRush.scx'),
#  ('CUNYBot', 'StyxZ', '\\(2\\)HeartbreakRidge.scx'),
#  ('CUNYBot', 'StyxZ', '\\(4\\)FightingSpirit.scx'),
#  ('CUNYBot', 'StyxZ', '\\(3\\)PowerBond.scx'),
#  ('CUNYBot', 'StyxZ', '\\(2\\)Overwatch2.2.scx'),
#  ('CUNYBot', 'ZZZKBot', '\\(4\\)CircuitBreaker.scx'),
#  ('CUNYBot', 'ZZZKBot', '\\(3\\)Aztec2.1.scx'),
#  ('CUNYBot', 'ZZZKBot', '\\(2\\)BlueStorm1.2.scx'),
#  ('CUNYBot', 'ZZZKBot', '\\(4\\)Gladiator1.1.scx'),
#  ('CUNYBot', 'ZZZKBot', '\\(3\\)GoldRush.scx'),
#  ('CUNYBot', 'ZZZKBot', '\\(2\\)HeartbreakRidge.scx'),
#  ('CUNYBot', 'ZZZKBot', '\\(4\\)FightingSpirit.scx'),
#  ('CUNYBot', 'ZZZKBot', '\\(3\\)PowerBond.scx'),
#  ('CUNYBot', 'ZZZKBot', '\\(2\\)Overwatch2.2.scx'),
#  ('CUNYBot', 'TCPZerg', '\\(4\\)CircuitBreaker.scx'),
#  ('CUNYBot', 'TCPZerg', '\\(3\\)Aztec2.1.scx'),
#  ('CUNYBot', 'TCPZerg', '\\(2\\)BlueStorm1.2.scx'),
#  ('CUNYBot', 'TCPZerg', '\\(4\\)Gladiator1.1.scx'),
#  ('CUNYBot', 'TCPZerg', '\\(3\\)GoldRush.scx'),
#  ('CUNYBot', 'TCPZerg', '\\(2\\)HeartbreakRidge.scx'),
#  ('CUNYBot', 'TCPZerg', '\\(4\\)FightingSpirit.scx'),
#  ('CUNYBot', 'TCPZerg', '\\(3\\)PowerBond.scx'),
#  ('CUNYBot', 'TCPZerg', '\\(2\\)Overwatch2.2.scx'),
#  ('Ecgberht', 'PurpleWave', '\\(4\\)CircuitBreaker.scx'),
#  ('Ecgberht', 'PurpleWave', '\\(3\\)Aztec2.1.scx'),
#  ('Ecgberht', 'PurpleWave', '\\(2\\)BlueStorm1.2.scx'),
#  ('Ecgberht', 'PurpleWave', '\\(4\\)Gladiator1.1.scx'),
#  ('Ecgberht', 'PurpleWave', '\\(3\\)GoldRush.scx'),
#  ('Ecgberht', 'PurpleWave', '\\(2\\)HeartbreakRidge.scx'),
#  ('Ecgberht', 'PurpleWave', '\\(4\\)FightingSpirit.scx'),
#  ('Ecgberht', 'PurpleWave', '\\(3\\)PowerBond.scx'),
#  ('Ecgberht', 'PurpleWave', '\\(2\\)Overwatch2.2.scx'),
#  ('Ecgberht', 'Halo', '\\(4\\)CircuitBreaker.scx'),
#  ('Ecgberht', 'Halo', '\\(3\\)Aztec2.1.scx'),
#  ('Ecgberht', 'Halo', '\\(2\\)BlueStorm1.2.scx'),
#  ('Ecgberht', 'Halo', '\\(4\\)Gladiator1.1.scx'),
#  ('Ecgberht', 'Halo', '\\(3\\)GoldRush.scx'),
#  ('Ecgberht', 'Halo', '\\(2\\)HeartbreakRidge.scx'),
#  ('Ecgberht', 'Halo', '\\(4\\)FightingSpirit.scx'),
#  ('Ecgberht', 'Halo', '\\(3\\)PowerBond.scx'),
#  ('Ecgberht', 'Halo', '\\(2\\)Overwatch2.2.scx'),
#  ('Ecgberht', 'Crona', '\\(4\\)CircuitBreaker.scx'),
#  ('Ecgberht', 'Crona', '\\(3\\)Aztec2.1.scx'),
#  ('Ecgberht', 'Crona', '\\(2\\)BlueStorm1.2.scx'),
#  ('Ecgberht', 'Crona', '\\(4\\)Gladiator1.1.scx'),
#  ('Ecgberht', 'Crona', '\\(3\\)GoldRush.scx'),
#  ('Ecgberht', 'Crona', '\\(2\\)HeartbreakRidge.scx'),
#  ('Ecgberht', 'Crona', '\\(4\\)FightingSpirit.scx'),
#  ('Ecgberht', 'Crona', '\\(3\\)PowerBond.scx'),
#  ('Ecgberht', 'Crona', '\\(2\\)Overwatch2.2.scx'),
#  ('Ecgberht', 'StyxZ', '\\(4\\)CircuitBreaker.scx'),
#  ('Ecgberht', 'StyxZ', '\\(3\\)Aztec2.1.scx'),
#  ('Ecgberht', 'StyxZ', '\\(2\\)BlueStorm1.2.scx'),
#  ('Ecgberht', 'StyxZ', '\\(4\\)Gladiator1.1.scx'),
#  ('Ecgberht', 'StyxZ', '\\(3\\)GoldRush.scx'),
#  ('Ecgberht', 'StyxZ', '\\(2\\)HeartbreakRidge.scx'),
#  ('Ecgberht', 'StyxZ', '\\(4\\)FightingSpirit.scx'),
#  ('Ecgberht', 'StyxZ', '\\(3\\)PowerBond.scx'),
#  ('Ecgberht', 'StyxZ', '\\(2\\)Overwatch2.2.scx'),
#  ('Ecgberht', 'ZZZKBot', '\\(4\\)CircuitBreaker.scx'),
#  ('Ecgberht', 'ZZZKBot', '\\(3\\)Aztec2.1.scx'),
#  ('Ecgberht', 'ZZZKBot', '\\(2\\)BlueStorm1.2.scx'),
#  ('Ecgberht', 'ZZZKBot', '\\(4\\)Gladiator1.1.scx'),
#  ('Ecgberht', 'ZZZKBot', '\\(3\\)GoldRush.scx'),
#  ('Ecgberht', 'ZZZKBot', '\\(2\\)HeartbreakRidge.scx'),
#  ('Ecgberht', 'ZZZKBot', '\\(4\\)FightingSpirit.scx'),
#  ('Ecgberht', 'ZZZKBot', '\\(3\\)PowerBond.scx'),
#  ('Ecgberht', 'ZZZKBot', '\\(2\\)Overwatch2.2.scx'),
#  ('Ecgberht', 'TCPZerg', '\\(4\\)CircuitBreaker.scx'),
#  ('Ecgberht', 'TCPZerg', '\\(3\\)Aztec2.1.scx'),
#  ('Ecgberht', 'TCPZerg', '\\(2\\)BlueStorm1.2.scx'),
#  ('Ecgberht', 'TCPZerg', '\\(4\\)Gladiator1.1.scx'),
#  ('Ecgberht', 'TCPZerg', '\\(3\\)GoldRush.scx'),
#  ('Ecgberht', 'TCPZerg', '\\(2\\)HeartbreakRidge.scx'),
#  ('Ecgberht', 'TCPZerg', '\\(4\\)FightingSpirit.scx'),
#  ('Ecgberht', 'TCPZerg', '\\(3\\)PowerBond.scx'),
#  ('Ecgberht', 'TCPZerg', '\\(2\\)Overwatch2.2.scx'),
#  ('PurpleWave', 'Halo', '\\(4\\)CircuitBreaker.scx'),
#  ('PurpleWave', 'Halo', '\\(3\\)Aztec2.1.scx'),
#  ('PurpleWave', 'Halo', '\\(2\\)BlueStorm1.2.scx'),
#  ('PurpleWave', 'Halo', '\\(4\\)Gladiator1.1.scx'),
#  ('PurpleWave', 'Halo', '\\(3\\)GoldRush.scx'),
#  ('PurpleWave', 'Halo', '\\(2\\)HeartbreakRidge.scx'),
#  ('PurpleWave', 'Halo', '\\(4\\)FightingSpirit.scx'),
#  ('PurpleWave', 'Halo', '\\(3\\)PowerBond.scx'),
#  ('PurpleWave', 'Halo', '\\(2\\)Overwatch2.2.scx'),
#  ('PurpleWave', 'Crona', '\\(4\\)CircuitBreaker.scx'),
#  ('PurpleWave', 'Crona', '\\(3\\)Aztec2.1.scx'),
#  ('PurpleWave', 'Crona', '\\(2\\)BlueStorm1.2.scx'),
#  ('PurpleWave', 'Crona', '\\(4\\)Gladiator1.1.scx'),
#  ('PurpleWave', 'Crona', '\\(3\\)GoldRush.scx'),
#  ('PurpleWave', 'Crona', '\\(2\\)HeartbreakRidge.scx'),
#  ('PurpleWave', 'Crona', '\\(4\\)FightingSpirit.scx'),
#  ('PurpleWave', 'Crona', '\\(3\\)PowerBond.scx'),
#  ('PurpleWave', 'Crona', '\\(2\\)Overwatch2.2.scx'),
#  ('PurpleWave', 'StyxZ', '\\(4\\)CircuitBreaker.scx'),
#  ('PurpleWave', 'StyxZ', '\\(3\\)Aztec2.1.scx'),
#  ('PurpleWave', 'StyxZ', '\\(2\\)BlueStorm1.2.scx'),
#  ('PurpleWave', 'StyxZ', '\\(4\\)Gladiator1.1.scx'),
#  ('PurpleWave', 'StyxZ', '\\(3\\)GoldRush.scx'),
#  ('PurpleWave', 'StyxZ', '\\(2\\)HeartbreakRidge.scx'),
#  ('PurpleWave', 'StyxZ', '\\(4\\)FightingSpirit.scx'),
#  ('PurpleWave', 'StyxZ', '\\(3\\)PowerBond.scx'),
#  ('PurpleWave', 'StyxZ', '\\(2\\)Overwatch2.2.scx'),
#  ('PurpleWave', 'ZZZKBot', '\\(4\\)CircuitBreaker.scx'),
#  ('PurpleWave', 'ZZZKBot', '\\(3\\)Aztec2.1.scx'),
#  ('PurpleWave', 'ZZZKBot', '\\(2\\)BlueStorm1.2.scx'),
#  ('PurpleWave', 'ZZZKBot', '\\(4\\)Gladiator1.1.scx'),
#  ('PurpleWave', 'ZZZKBot', '\\(3\\)GoldRush.scx'),
#  ('PurpleWave', 'ZZZKBot', '\\(2\\)HeartbreakRidge.scx'),
#  ('PurpleWave', 'ZZZKBot', '\\(4\\)FightingSpirit.scx'),
#  ('PurpleWave', 'ZZZKBot', '\\(3\\)PowerBond.scx'),
#  ('PurpleWave', 'ZZZKBot', '\\(2\\)Overwatch2.2.scx'),
#  ('PurpleWave', 'TCPZerg', '\\(4\\)CircuitBreaker.scx'),
#  ('PurpleWave', 'TCPZerg', '\\(3\\)Aztec2.1.scx'),
#  ('PurpleWave', 'TCPZerg', '\\(2\\)BlueStorm1.2.scx'),
#  ('PurpleWave', 'TCPZerg', '\\(4\\)Gladiator1.1.scx'),
#  ('PurpleWave', 'TCPZerg', '\\(3\\)GoldRush.scx'),
#  ('PurpleWave', 'TCPZerg', '\\(2\\)HeartbreakRidge.scx'),
#  ('PurpleWave', 'TCPZerg', '\\(4\\)FightingSpirit.scx'),
#  ('PurpleWave', 'TCPZerg', '\\(3\\)PowerBond.scx'),
#  ('PurpleWave', 'TCPZerg', '\\(2\\)Overwatch2.2.scx'),
#  ('Halo', 'Crona', '\\(4\\)CircuitBreaker.scx'),
#  ('Halo', 'Crona', '\\(3\\)Aztec2.1.scx'),
#  ('Halo', 'Crona', '\\(2\\)BlueStorm1.2.scx'),
#  ('Halo', 'Crona', '\\(4\\)Gladiator1.1.scx'),
#  ('Halo', 'Crona', '\\(3\\)GoldRush.scx'),
#  ('Halo', 'Crona', '\\(2\\)HeartbreakRidge.scx'),
#  ('Halo', 'Crona', '\\(4\\)FightingSpirit.scx'),
#  ('Halo', 'Crona', '\\(3\\)PowerBond.scx'),
#  ('Halo', 'Crona', '\\(2\\)Overwatch2.2.scx'),
#  ('Halo', 'StyxZ', '\\(4\\)CircuitBreaker.scx'),
#  ('Halo', 'StyxZ', '\\(3\\)Aztec2.1.scx'),
#  ('Halo', 'StyxZ', '\\(2\\)BlueStorm1.2.scx'),
#  ('Halo', 'StyxZ', '\\(4\\)Gladiator1.1.scx'),
#  ('Halo', 'StyxZ', '\\(3\\)GoldRush.scx'),
#  ('Halo', 'StyxZ', '\\(2\\)HeartbreakRidge.scx'),
#  ('Halo', 'StyxZ', '\\(4\\)FightingSpirit.scx'),
#  ('Halo', 'StyxZ', '\\(3\\)PowerBond.scx'),
#  ('Halo', 'StyxZ', '\\(2\\)Overwatch2.2.scx'),
#  ('Halo', 'ZZZKBot', '\\(4\\)CircuitBreaker.scx'),
#  ('Halo', 'ZZZKBot', '\\(3\\)Aztec2.1.scx'),
#  ('Halo', 'ZZZKBot', '\\(2\\)BlueStorm1.2.scx'),
#  ('Halo', 'ZZZKBot', '\\(4\\)Gladiator1.1.scx'),
#  ('Halo', 'ZZZKBot', '\\(3\\)GoldRush.scx'),
#  ('Halo', 'ZZZKBot', '\\(2\\)HeartbreakRidge.scx'),
#  ('Halo', 'ZZZKBot', '\\(4\\)FightingSpirit.scx'),
#  ('Halo', 'ZZZKBot', '\\(3\\)PowerBond.scx'),
#  ('Halo', 'ZZZKBot', '\\(2\\)Overwatch2.2.scx'),
#  ('Halo', 'TCPZerg', '\\(4\\)CircuitBreaker.scx'),
#  ('Halo', 'TCPZerg', '\\(3\\)Aztec2.1.scx'),
#  ('Halo', 'TCPZerg', '\\(2\\)BlueStorm1.2.scx'),
#  ('Halo', 'TCPZerg', '\\(4\\)Gladiator1.1.scx'),
#  ('Halo', 'TCPZerg', '\\(3\\)GoldRush.scx'),
#  ('Halo', 'TCPZerg', '\\(2\\)HeartbreakRidge.scx'),
#  ('Halo', 'TCPZerg', '\\(4\\)FightingSpirit.scx'),
#  ('Halo', 'TCPZerg', '\\(3\\)PowerBond.scx'),
#  ('Halo', 'TCPZerg', '\\(2\\)Overwatch2.2.scx'),
#  ('Crona', 'StyxZ', '\\(4\\)CircuitBreaker.scx'),
#  ('Crona', 'StyxZ', '\\(3\\)Aztec2.1.scx'),
#  ('Crona', 'StyxZ', '\\(2\\)BlueStorm1.2.scx'),
#  ('Crona', 'StyxZ', '\\(4\\)Gladiator1.1.scx'),
#  ('Crona', 'StyxZ', '\\(3\\)GoldRush.scx'),
#  ('Crona', 'StyxZ', '\\(2\\)HeartbreakRidge.scx'),
#  ('Crona', 'StyxZ', '\\(4\\)FightingSpirit.scx'),
#  ('Crona', 'StyxZ', '\\(3\\)PowerBond.scx'),
#  ('Crona', 'StyxZ', '\\(2\\)Overwatch2.2.scx'),
#  ('Crona', 'ZZZKBot', '\\(4\\)CircuitBreaker.scx'),
#  ('Crona', 'ZZZKBot', '\\(3\\)Aztec2.1.scx'),
#  ('Crona', 'ZZZKBot', '\\(2\\)BlueStorm1.2.scx'),
#  ('Crona', 'ZZZKBot', '\\(4\\)Gladiator1.1.scx'),
#  ('Crona', 'ZZZKBot', '\\(3\\)GoldRush.scx'),
#  ('Crona', 'ZZZKBot', '\\(2\\)HeartbreakRidge.scx'),
#  ('Crona', 'ZZZKBot', '\\(4\\)FightingSpirit.scx'),
#  ('Crona', 'ZZZKBot', '\\(3\\)PowerBond.scx'),
#  ('Crona', 'ZZZKBot', '\\(2\\)Overwatch2.2.scx'),
#  ('Crona', 'TCPZerg', '\\(4\\)CircuitBreaker.scx'),
#  ('Crona', 'TCPZerg', '\\(3\\)Aztec2.1.scx'),
#  ('Crona', 'TCPZerg', '\\(2\\)BlueStorm1.2.scx'),
#  ('Crona', 'TCPZerg', '\\(4\\)Gladiator1.1.scx'),
#  ('Crona', 'TCPZerg', '\\(3\\)GoldRush.scx'),
#  ('Crona', 'TCPZerg', '\\(2\\)HeartbreakRidge.scx'),
#  ('Crona', 'TCPZerg', '\\(4\\)FightingSpirit.scx'),
#  ('Crona', 'TCPZerg', '\\(3\\)PowerBond.scx'),
#  ('Crona', 'TCPZerg', '\\(2\\)Overwatch2.2.scx'),
#  ('StyxZ', 'ZZZKBot', '\\(4\\)CircuitBreaker.scx'),
#  ('StyxZ', 'ZZZKBot', '\\(3\\)Aztec2.1.scx'),
#  ('StyxZ', 'ZZZKBot', '\\(2\\)BlueStorm1.2.scx'),
#  ('StyxZ', 'ZZZKBot', '\\(4\\)Gladiator1.1.scx'),
#  ('StyxZ', 'ZZZKBot', '\\(3\\)GoldRush.scx'),
#  ('StyxZ', 'ZZZKBot', '\\(2\\)HeartbreakRidge.scx'),
#  ('StyxZ', 'ZZZKBot', '\\(4\\)FightingSpirit.scx'),
#  ('StyxZ', 'ZZZKBot', '\\(3\\)PowerBond.scx'),
#  ('StyxZ', 'ZZZKBot', '\\(2\\)Overwatch2.2.scx'),
#  ('StyxZ', 'TCPZerg', '\\(4\\)CircuitBreaker.scx'),
#  ('StyxZ', 'TCPZerg', '\\(3\\)Aztec2.1.scx'),
#  ('StyxZ', 'TCPZerg', '\\(2\\)BlueStorm1.2.scx'),
#  ('StyxZ', 'TCPZerg', '\\(4\\)Gladiator1.1.scx'),
#  ('StyxZ', 'TCPZerg', '\\(3\\)GoldRush.scx'),
#  ('StyxZ', 'TCPZerg', '\\(2\\)HeartbreakRidge.scx'),
#  ('StyxZ', 'TCPZerg', '\\(4\\)FightingSpirit.scx'),
#  ('StyxZ', 'TCPZerg', '\\(3\\)PowerBond.scx'),
#  ('StyxZ', 'TCPZerg', '\\(2\\)Overwatch2.2.scx'),
#  ('ZZZKBot', 'TCPZerg', '\\(4\\)CircuitBreaker.scx'),
#  ('ZZZKBot', 'TCPZerg', '\\(3\\)Aztec2.1.scx'),
#  ('ZZZKBot', 'TCPZerg', '\\(2\\)BlueStorm1.2.scx'),
#  ('ZZZKBot', 'TCPZerg', '\\(4\\)Gladiator1.1.scx'),
#  ('ZZZKBot', 'TCPZerg', '\\(3\\)GoldRush.scx'),
#  ('ZZZKBot', 'TCPZerg', '\\(2\\)HeartbreakRidge.scx'),
#  ('ZZZKBot', 'TCPZerg', '\\(4\\)FightingSpirit.scx'),
#  ('ZZZKBot', 'TCPZerg', '\\(3\\)PowerBond.scx'),
#  ('ZZZKBot', 'TCPZerg', '\\(2\\)Overwatch2.2.scx')]
